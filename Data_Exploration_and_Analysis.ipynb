# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # load the dataset

# %%
# Read the CSV file from the response content
df= pd.read_csv('creditcard.csv')

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Reading and understanding the data

# %%
# Reading the dataset

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# In this data set total number of column is *30* and number of row is *284807*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.759061e-12      1.958696  -56.407510     -0.920373
# V2      284807.0 -8.251130e-13      1.651309  -72.715728     -0.598550
# V3      284807.0 -9.654937e-13      1.516255  -48.325589     -0.890365
# V4      284807.0  8.321385e-13      1.415869   -5.683171     -0.848640
# V5      284807.0  1.649999e-13      1.380247 -113.743307     -0.691597
# V6      284807.0  4.248366e-13      1.332271  -26.160506     -0.768296
# V7      284807.0 -3.054600e-13      1.237094  -43.557242     -0.554076
# V8      284807.0  8.777971e-14      1.194353  -73.216718     -0.208630
# V9      284807.0 -1.179749e-12      1.098632  -13.434066     -0.643098
# V10     284807.0  7.092545e-13      1.088850  -24.588262     -0.535426
# V11     284807.0  1.874948e-12      1.020713   -4.797473     -0.762494
# ...

# %% [markdown]
# # Handling the missing values

# %%
mising=df.isnull().sum()/len(df)*100
mising
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %% [markdown]
# We can see that there is no missing values in any of the columns. Hence, there is no problem with null values in the entire dataset.

# %% [markdown]
# # Checking the distribution of the dependent variable into the data set
# Here *class* is  he dependendt variable here and other is independet variable

# %%
classes=df['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# *    Here 0 means normal transection
#
# *    Here 1 means fraud transection

# %% [markdown]
# # finding the share of the both transection

# %%
normal_transection=classes[0]/len(df)*100
fraud_transection=classes[1]/len(df)*100
print(f'the share of normal transection is {(normal_transection)}')
print(f'the share of fraud transection is {fraud_transection}')
# Out:
# the share of normal transection is 99.82725143693798
# the share of fraud transection is 0.1727485630620034

# %% [markdown]
# We can see that there is only 0.17% frauds. We will take care of the class imbalance later.

# %% [markdown]
# # finding the sum visual here

# %%
! pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("your_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  2.63it/s]

# %% [markdown]
# # Bar plot for the percentage of fraudulent vs non-fraudulent transcations

# %%
# Bar plot for the percentage of fraudulent vs non-fraudulent transcations
fraud_percentage = {'Class':['Non-Fraudulent', 'Fraudulent'], 'Percentage':[normal_transection, fraud_transection]}
df_fraud_percentage = pd.DataFrame(fraud_percentage)
sns.barplot(x='Class',y='Percentage', data=df_fraud_percentage)
plt.title('Percentage of fraudulent vs non-fraudulent transcations')
plt.savefig('fraud_percentage.jpg')
plt.show()

# %% [markdown]
# ## Outliers treatment

# %% [markdown]
# We are not performing any outliers treatment for this particular dataset. Because all the columns are already PCA transformed, which assumed that the outlier values are taken care while transforming the data.

# %% [markdown]
# ### Observe the distribution of classes with time

# %%
# Creating fraudulent dataframe
data_fraud = df[df['Class'] == 1]
# Creating non fraudulent dataframe
data_non_fraud = df[df['Class'] == 0]

# %%
# Distribution plot
plt.figure(figsize=(8,5))
ax = sns.distplot(data_fraud['Time'],label='fraudulent',hist=False)
ax = sns.distplot(data_non_fraud['Time'],label='non fraudulent',hist=False)
ax.set(xlabel='Seconds elapsed between the transction and the first transction')
plt.legend()
plt.savefig('time_distribution.jpg')
plt.show()

# %% [markdown]
# ##### Analysis
# We do not see any specific pattern for the fraudulent and non-fraudulent transctions with respect to Time.
# Hence, we can drop the `Time` column.

# %%
# droping the time column
df.drop('Time',axis=1,inplace=True)

# %% [markdown]
# # Now here we find the relation between class with amount

# %%
# Distribution plot
plt.figure(figsize=(8,5))
ax = sns.distplot(data_fraud['Amount'],label='fraudulent',hist=False)
ax = sns.distplot(data_non_fraud['Time'],label='non fraudulent',hist=False)
ax.set(xlabel='Transction Amount')
plt.legend()
plt.savefig('amount_distribution.jpg')
plt.show()

# %% [markdown]
# ##### Analysis
# We can see that the fraudulent transctions are mostly densed in the lower range of amount, whereas the non-fraudulent transctions are spreaded throughout low to high range of amount.

# %%
# plot the graph of amount
sns.barplot(x='Class',y='Amount',data=df)
plt.title('Amount vs Class')
plt.savefig('amount_boxplot.jpg')
plt.show()

# %% [markdown]
# ## Train-Test Split

# %%
# Import library
from sklearn.model_selection import train_test_split

# %%
# Putting feature variables into X
X = df.drop(['Class'], axis=1)
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
# Putting target variable to y
y = df['Class']
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
# Splitting data into train and test set 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)

# %%
X_train.shape
# Out:
# (227845, 29)

# %%
#Using Pearson Correlation
plt.figure(figsize=(24,20))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.PuOr)
plt.show()

# %% [markdown]
# # Feature Scaling

# %%
# Standardization method
from sklearn.preprocessing import StandardScaler

# %%
# Instantiate the Scaler
scaler = StandardScaler()

# %%
# Fit the data into scaler and transform
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])

# %%
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 201788  2.023734 -0.429219 -0.691061 -0.201461 -0.162486  0.283718 -0.674694
# 179369 -0.145286  0.736735  0.543226  0.892662  0.350846  0.089253  0.626708
# 73138  -3.015846 -1.920606  1.229574  0.721577  1.089918 -0.195727 -0.462586
# 208679  1.851980 -1.007445 -1.499762 -0.220770 -0.568376 -1.232633  0.248573
# 206534  2.237844 -0.551513 -1.426515 -0.924369 -0.401734 -1.438232 -0.119942
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 201788  0.192230  1.124319 -0.037763  ... -0.171390 -0.195207 -0.477813
# 179369 -0.049137 -0.732566  0.297692  ...  0.206709 -0.124288 -0.263560
# 73138   0.919341 -0.612193 -0.966197  ...  0.842838  0.274911 -0.319550
# 208679 -0.539483 -0.813368  0.785431  ... -0.196551 -0.406722 -0.899081
# 206534 -0.449263 -0.717258  0.851668  ... -0.045417  0.050447  0.125601
#
# ...

# %% [markdown]
# # Scaling the test set
# We don't fit scaler on the test set. We only transform the test set.

# %%
# Transform the test set
X_test['Amount'] = scaler.transform(X_test[['Amount']])
X_test.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 49089   1.229452 -0.235478 -0.627166  0.419877  1.797014  4.069574 -0.896223
# 154704  2.016893 -0.088751 -2.989257 -0.142575  2.675427  3.332289 -0.652336
# 67247   0.535093 -1.469185  0.868279  0.385462 -1.439135  0.368118 -0.499370
# 251657  2.128486 -0.117215 -1.513910  0.166456  0.359070 -0.540072  0.116023
# 201903  0.558593  1.587908 -2.368767  5.124413  2.171788 -0.500419  1.059829
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 49089   1.036103  0.745991 -0.147304  ... -0.057922 -0.170060 -0.288750
# 154704  0.752811  1.962566 -1.025024  ... -0.147619 -0.184153 -0.089661
# 67247   0.303698  1.042073 -0.437209  ...  0.437685  0.028010 -0.384708
# 251657 -0.216140  0.680314  0.079977  ... -0.227278 -0.357993 -0.905085
# 201903 -0.254233 -1.959060  0.948915  ...  0.249457 -0.035049  0.271455
#
# ...

# %% [markdown]
# # Checking the Skewness

# %%
# Listing the columns
cols = X_train.columns
cols
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
# Plotting the distribution of the variables (skewness) of all the columns
k=0
plt.figure(figsize=(17,28))
for col in cols :
    k=k+1
    plt.subplot(6, 5,k)
    sns.distplot(X_train[col])
    plt.title(col+' '+str(X_train[col].skew()))
    plt.savefig('distribution.png')
    plt.show()

# %% [markdown]
# We see that there are many variables, which are heavily skewed. We will mitigate the skewness only for those variables for bringing them into normal distribution.

# %% [markdown]
# # Mitigate skweness with PowerTransformer

# %%
# Importing PowerTransformer
from sklearn.preprocessing import PowerTransformer
# Instantiate the powertransformer
pt = PowerTransformer(method='yeo-johnson', standardize=True, copy=False)
# Fit and transform the PT on training data
X_train[cols] = pt.fit_transform(X_train)

# %%
# Transform the test set
X_test[cols] = pt.transform(X_test)

# %%
# Plotting the distribution of the variables (skewness) of all the columns
k=0
plt.figure(figsize=(17,28))
for col in cols :
    k=k+1
    plt.subplot(6, 5,k)
    sns.distplot(X_train[col])
    plt.title(col+' '+str(X_train[col].skew()))

# %% [markdown]
# # Handling data imbalance
# As we see that the data is heavily imbalanced, We will try several approaches for handling data imbalance.
#
# - Undersampling :- Here for balancing the class distribution, the non-fraudulent transctions count will be reduced to 396 (similar count of fraudulent transctions)
# - Oversampling :- Here we will make the same count of non-fraudulent transctions as fraudulent transctions.
# - SMOTE :- Synthetic minority oversampling technique. It is another oversampling technique, which uses nearest neighbor algorithm to create synthetic data.
# - Adasyn:- This is similar to SMOTE with minor changes that the new synthetic data is generated on the region of low density of imbalanced data points.

# %% [markdown]
# # Undersampling

# %%
! pip install imbalanced-learn
# Out:
# ...
#    ---------------------------------------- 0.0/258.3 kB ? eta -:--:--
#    --------------------------------------  256.0/258.3 kB 15.4 MB/s eta 0:00:01
#    --------------------------------------  256.0/258.3 kB 15.4 MB/s eta 0:00:01
#    ---------------------------------------- 258.3/258.3 kB 1.6 MB/s eta 0:00:00
# ...

# %%
# Importing undersampler library
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
# instantiating the random undersampler
rus = RandomUnderSampler()
# resampling X, y
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# %%
# Befor sampling class distribution
print('Before sampling class distribution:-',Counter(y_train))
# new class distribution
print('New class distribution:-',Counter(y_train_rus))
# Out:
# Before sampling class distribution:- Counter({0: 227449, 1: 396})
# New class distribution:- Counter({0: 396, 1: 396})

# %% [markdown]
# # SMOTE (Synthetic Minority Oversampling Technique)

# %% [markdown]
# We are creating synthetic samples by doing upsampling using SMOTE(Synthetic Minority Oversampling Technique).

# %%
# Importing SMOTE
from imblearn.over_sampling import SMOTE

# %%
# Instantiate SMOTE
sm = SMOTE(random_state=27)
# Fitting SMOTE to the train set
X_train_smote, y_train_smote = sm.fit_resample(X, y)

# %%
print('Before SMOTE oversampling X_train shape=',X_train.shape)
print('After SMOTE oversampling X_train shape=',X_train_smote.shape)
# Out:
# Before SMOTE oversampling X_train shape= (227845, 29)
# After SMOTE oversampling X_train shape= (568630, 29)

# %%
X_train_smote.shape
# Out:
# (568630, 29)

# %%
X_train.to_csv('X_train.csv',index=False)
X_test.to_csv('X_test.csv',index=False)
y_train.to_csv('y_train.csv',index=False)
y_test.to_csv('y_test.csv',index=False)

# %%
# 'download the cleaned  DataFrame
df.to_csv('X_train_smote.csv', index=False)
df.to_csv('y_train_smote.csv', index=False)



print("File saved as creditcard_clean_data.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[77], line 2
#       1 # 'download the cleaned  DataFrame
# ----> 2 df.to_csv('X_train_smote.csv', index=False)
#       3 df.to_csv('y_train_smote.csv', index=False)
#       7 print("File saved as creditcard_clean_data.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
import requests
import io
def data_exploration(url):

  # Download the dataset
  response = requests.get(url)

  # Read the CSV file from the response content
  df = pd.read_csv(io.StringIO(response.text))

  # Print the first few rows of the dataframe
  print(df.head())

  # Print the shape of the dataframe
  print(df.shape)

  # Print information about the dataframe
  print(df.info())

  # Print the descriptive statistics of the dataframe
  print(df.describe().T)

  # Check for missing values
  missing = df.isnull().sum() / len(df) * 100
  print(missing)

  # Check the distribution of the dependent variable
  classes = df['Class'].value_counts()
  print(classes)

  # Calculate the share of normal and fraudulent transactions
  normal_transection = classes[0] / len(df) * 100
  fraud_transection = classes[1] / len(df) * 100
  print(f'The share of normal transactions is {normal_transection}')
  print(f'The share of fraudulent transactions is {fraud_transection}')

  return df

# Call the function with the URL
df = data_exploration(url)
